# %% [markdown]
# <a href="https://colab.research.google.com/github/danielozeiasherzog-lgtm/Aula-03-PCD/blob/main/Atividade_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 4
b = 7
c = 2

media = (a + b + c)/3

print("Nota 1: ", a)
print("Nota 2: ", b)
print("Nota 3: ", c)
print("A média das 3 notas é: ", media)
# Out:
# Nota 1:  4
# Nota 2:  7
# Nota 3:  2
# A média das 3 notas é:  4.333333333333333
