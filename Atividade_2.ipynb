# %% [markdown]
# <a href="https://colab.research.google.com/github/danielozeiasherzog-lgtm/Aula-03-PCD/blob/main/Atividade_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = str (input("Informe o nome do estudante: "))
a = float(input("Informe o valor da nota: "))
b = float(input("Informe o valor da nota: "))
c = float(input("Informe o valor da nota: "))


media = (a + b + c)/3

print(nome)
print("Nota 1: ", a)
print("Nota 2: ", b)
print("Nota 3: ", c)
print("A média das 3 notas é: ", media)
# Out:
# Informe o nome do estudante: Daniel
# Informe o valor da nota: 2
# Informe o valor da nota: 3
# Informe o valor da nota: 4
# Daniel
# Nota 1:  2.0
# Nota 2:  3.0
# Nota 3:  4.0
# A média das 3 notas é:  3.0

# %%
nome = str (input("Informe o nome do estudante: "))
a = int(input("Informe o valor da nota: "))
b = int(input("Informe o valor da nota: "))
c = int(input("Informe o valor da nota: "))

media = (mediaDecimal)/3

print(nome)
print("Nota 1: ", a)
print("Nota 2: ", b)
print("Nota 3: ", c)
print("A média das 3 notas é: ", media)
# Out:
# Informe o nome do estudante: Daniel
# Informe o valor da nota: 2
# Informe o valor da nota: 3
# Informe o valor da nota: 4
# Daniel
# Nota 1:  2
# Nota 2:  3
# Nota 3:  4
# A média das 3 notas é:  3.0
