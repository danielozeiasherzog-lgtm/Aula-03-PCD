# %% [markdown]
# <a href="https://colab.research.google.com/github/danielozeiasherzog-lgtm/Materia_PCD/blob/main/Aula04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def hello():
  print("Olá Mundo!")

hello()
# Out:
# Olá Mundo!

# %%
notas_provas = [9, 6.5, 3.4, 8.5]
soma = 0
for nota in notas_provas:
  soma = soma + nota

media = soma / 4
print("Média= ", media)
# Out:
# Média=  6.85

# %%
for i in range(20, 10, -3):
  print(i)
# Out:
# 20
# 17
# 14
# 11

# %%
for i in range(1, 10, 1):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
senha = "112233"
digitado = " "
while(digitado != senha):
  digitado = input("Digite a senha: ")
  if digitado == senha :
    print('Acesso liberado ')
  else:
    print('Senha incorreta. Tente novamente')
# Out:
# Digite a senha: 112233
# Acesso liberado

# %%
nota = float (input("Informe o valor da sua nota: "))
if nota < 60:
  print("Sua nota {} não foi suficiente para ser aprovado!" .format(nota))
elif nota > 60 and nota < 74:
  print("Sua nota {} foi C! " .format(nota))
elif nota > 75 and nota < 90:
  print("Sua nota {} foi B! " .format(nota))
else:
  print("Sua nota {} foi A! " .format(nota))
# Out:
# Informe o valor da sua nota: 75
# Sua nota 75.0 foi A!

# %%
nota = float (input("Informe o valor da sua nota: "))
if nota < 60:
  print("Sua nota {} não foi suficiente para ser aprovado!" .format(nota))
else:
  print("Sua nota {} foi suficiente para ser aprovado, parabéns! " .format(nota))
  print("Nota boa")
# Out:
# Informe o valor da sua nota: 70
# Sua nota 70.0 foi suficiente para ser aprovado, parabéns!
# Nota boa

# %%
nota = float (input("Informe o valor da sua nota: "))
if nota < 60:
  print("Sua nota {} não foi suficiente para ser aprovado!" .format(nota))
else:
  print("Sua nota {} foi suficiente para ser aprovado, parabéns! " .format(nota))
