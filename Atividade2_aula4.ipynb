# %% [markdown]
# <a href="https://colab.research.google.com/github/danielozeiasherzog-lgtm/Materia_PCD/blob/main/Atividade2_aula4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math

n = float(input("Digite um número: "))

b = n
p = (b + (n / b)) / 2

while abs(n - (p ** 2)) >= 0.0001:
    b = p
    p = (b + (n / b)) / 2

print("Raiz pelo método de Newton:", p)
print("Raiz usando SQRT:", math.sqrt(n))
# Out:
# Digite um número: 8
# Raiz pelo método de Newton: 2.8284271250498643
# Raiz usando SQRT: 2.8284271247461903
